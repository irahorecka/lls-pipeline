# %% [markdown]
# ## ZARR COMPRESSION IN A MULTIPROCESSING ENVIRONMENT
#
# "Parallel computing and synchronization"<br>
# https://zarr.readthedocs.io/en/stable/tutorial.html#parallel-computing-and-synchronization
#
# Query "multi-processing zarr" in Google for useful discussions

# %%
# A standard multiprocessing library mated to zarr - a standard example of writing to zarr file using multiprocessing.
# View discussion and source code here: https://github.com/zarr-developers/zarr-python/issues/199
# View block / hang discussion here: https://github.com/zarr-developers/numcodecs/issues/41
# View using Dask for multi-threading here: https://clouds.eos.ubc.ca/~phil/courses/parallel_python/03_dask_and_zarr.html

import zarr
import numpy as np
from pprint import pprint
import multiprocessing
from zarr import blosc
blosc.set_nthreads(20)
blosc.use_threads=False  # This must be set to false to prevent locking in the blosc context 

# look into synchronized zarr API: https://zarr.readthedocs.io/en/stable/api/sync.html
synchronizer = zarr.ProcessSynchronizer('example.sync')
processed_zarr = zarr.hierarchy.open_group("test.zarr", 'a', synchronizer=synchronizer)

features_arr = np.random.random_sample((10000,20))
processed_zarr.create_dataset("features_arr", data=features_arr, shape=features_arr.shape, dtype="float64", overwrite=True)

ixs = np.arange(processed_zarr["features_arr"].shape[0])
slices = np.linspace(0, processed_zarr["features_arr"].shape[0]-1, 100, dtype=np.int32)

sliceIter = []
for i in range(len(slices)-1):
    sliceIter.append({
        "min" : ixs[slices[i]],
        "max" : ixs[slices[i+1]],
        "slice_num" : i,
    })
pprint(sliceIter)

### slices breakds up the np.arange of processed_zarr["features_arr"] into n number of slices in an np.linspace
#
def mem_instantiate(param_dict):
    min_ix = param_dict["min"]
    max_ix = param_dict["max"]
    slice_num = param_dict["slice_num"]

    ### never gets past loading the features
    instantiated_features = processed_zarr["features_arr"][min_ix:max_ix]
    print(slice_num, "features loaded")


pool = multiprocessing.Pool(processes=5)
pool.map(mem_instantiate, sliceIter)
pool.close()
pool.join()
# Out:
# [{'max': 101, 'min': 0, 'slice_num': 0},
#  {'max': 202, 'min': 101, 'slice_num': 1},
#  {'max': 303, 'min': 202, 'slice_num': 2},
#  {'max': 404, 'min': 303, 'slice_num': 3},
#  {'max': 505, 'min': 404, 'slice_num': 4},
#  {'max': 606, 'min': 505, 'slice_num': 5},
#  {'max': 707, 'min': 606, 'slice_num': 6},
#  {'max': 808, 'min': 707, 'slice_num': 7},
#  {'max': 909, 'min': 808, 'slice_num': 8},
#  {'max': 1010, 'min': 909, 'slice_num': 9},
#  {'max': 1111, 'min': 1010, 'slice_num': 10},
#  {'max': 1212, 'min': 1111, 'slice_num': 11},
#  {'max': 1313, 'min': 1212, 'slice_num': 12},
#  {'max': 1414, 'min': 1313, 'slice_num': 13},
#  {'max': 1515, 'min': 1414, 'slice_num': 14},
#  {'max': 1616, 'min': 1515, 'slice_num': 15},
#  {'max': 1717, 'min': 1616, 'slice_num': 16},
#  {'max': 1818, 'min': 1717, 'slice_num': 17},
#  {'max': 1919, 'min': 1818, 'slice_num': 18},
#  {'max': 2020, 'min': 1919, 'slice_num': 19},
#  {'max': 2121, 'min': 2020, 'slice_num': 20},
#  {'max': 2222, 'min': 2121, 'slice_num': 21},
#  {'max': 2323, 'min': 2222, 'slice_num': 22},
#  {'max': 2424, 'min': 2323, 'slice_num': 23},
#  {'max': 2525, 'min': 2424, 'slice_num': 24},
#  {'max': 2626, 'min': 2525, 'slice_num': 25},
#  {'max': 2727, 'min': 2626, 'slice_num': 26},
#  {'max': 2828, 'min': 2727, 'slice_num': 27},
#  {'max': 2929, 'min': 2828, 'slice_num': 28},
#  {'max': 3030, 'min': 2929, 'slice_num': 29},
#  {'max': 3131, 'min': 3030, 'slice_num': 30},
#  {'max': 3232, 'min': 3131, 'slice_num': 31},
#  {'max': 3333, 'min': 3232, 'slice_num': 32},
#  {'max': 3434, 'min': 3333, 'slice_num': 33},
#  {'max': 3535, 'min': 3434, 'slice_num': 34},
#  {'max': 3636, 'min': 3535, 'slice_num': 35},
#  {'max': 3737, 'min': 3636, 'slice_num': 36},
#  {'max': 3838, 'min': 3737, 'slice_num': 37},
#  {'max': 3939, 'min': 3838, 'slice_num': 38},
#  {'max': 4040, 'min': 3939, 'slice_num': 39},
#  {'max': 4141, 'min': 4040, 'slice_num': 40},
#  {'max': 4242, 'min': 4141, 'slice_num': 41},
#  {'max': 4343, 'min': 4242, 'slice_num': 42},
#  {'max': 4444, 'min': 4343, 'slice_num': 43},
#  {'max': 4545, 'min': 4444, 'slice_num': 44},
#  {'max': 4646, 'min': 4545, 'slice_num': 45},
#  {'max': 4747, 'min': 4646, 'slice_num': 46},
#  {'max': 4848, 'min': 4747, 'slice_num': 47},
#  {'max': 4949, 'min': 4848, 'slice_num': 48},
#  {'max': 5050, 'min': 4949, 'slice_num': 49},
#  {'max': 5151, 'min': 5050, 'slice_num': 50},
#  {'max': 5252, 'min': 5151, 'slice_num': 51},
#  {'max': 5353, 'min': 5252, 'slice_num': 52},
#  {'max': 5454, 'min': 5353, 'slice_num': 53},
#  {'max': 5555, 'min': 5454, 'slice_num': 54},
#  {'max': 5656, 'min': 5555, 'slice_num': 55},
#  {'max': 5757, 'min': 5656, 'slice_num': 56},
#  {'max': 5858, 'min': 5757, 'slice_num': 57},
#  {'max': 5959, 'min': 5858, 'slice_num': 58},
#  {'max': 6060, 'min': 5959, 'slice_num': 59},
#  {'max': 6161, 'min': 6060, 'slice_num': 60},
#  {'max': 6262, 'min': 6161, 'slice_num': 61},
#  {'max': 6363, 'min': 6262, 'slice_num': 62},
#  {'max': 6464, 'min': 6363, 'slice_num': 63},
#  {'max': 6565, 'min': 6464, 'slice_num': 64},
#  {'max': 6666, 'min': 6565, 'slice_num': 65},
#  {'max': 6767, 'min': 6666, 'slice_num': 66},
#  {'max': 6868, 'min': 6767, 'slice_num': 67},
#  {'max': 6969, 'min': 6868, 'slice_num': 68},
#  {'max': 7070, 'min': 6969, 'slice_num': 69},
#  {'max': 7171, 'min': 7070, 'slice_num': 70},
#  {'max': 7272, 'min': 7171, 'slice_num': 71},
#  {'max': 7373, 'min': 7272, 'slice_num': 72},
#  {'max': 7474, 'min': 7373, 'slice_num': 73},
#  {'max': 7575, 'min': 7474, 'slice_num': 74},
#  {'max': 7676, 'min': 7575, 'slice_num': 75},
#  {'max': 7777, 'min': 7676, 'slice_num': 76},
#  {'max': 7878, 'min': 7777, 'slice_num': 77},
#  {'max': 7979, 'min': 7878, 'slice_num': 78},
#  {'max': 8080, 'min': 7979, 'slice_num': 79},
#  {'max': 8181, 'min': 8080, 'slice_num': 80},
#  {'max': 8282, 'min': 8181, 'slice_num': 81},
#  {'max': 8383, 'min': 8282, 'slice_num': 82},
#  {'max': 8484, 'min': 8383, 'slice_num': 83},
#  {'max': 8585, 'min': 8484, 'slice_num': 84},
#  {'max': 8686, 'min': 8585, 'slice_num': 85},
#  {'max': 8787, 'min': 8686, 'slice_num': 86},
#  {'max': 8888, 'min': 8787, 'slice_num': 87},
#  {'max': 8989, 'min': 8888, 'slice_num': 88},
#  {'max': 9090, 'min': 8989, 'slice_num': 89},
#  {'max': 9191, 'min': 9090, 'slice_num': 90},
#  {'max': 9292, 'min': 9191, 'slice_num': 91},
#  {'max': 9393, 'min': 9292, 'slice_num': 92},
#  {'max': 9494, 'min': 9393, 'slice_num': 93},
#  {'max': 9595, 'min': 9494, 'slice_num': 94},
#  {'max': 9696, 'min': 9595, 'slice_num': 95},
#  {'max': 9797, 'min': 9696, 'slice_num': 96},
#  {'max': 9898, 'min': 9797, 'slice_num': 97},
#  {'max': 9999, 'min': 9898, 'slice_num': 98}]
# 0 features loaded
# 20 features loaded
# 21 features loaded
# 1 features loaded
# 2 features loaded
# 10 features loaded
# 3 features loaded
# 11 features loaded
# 4 features loaded
# 22 features loaded
# 23 features loaded
# 15 features loaded
# 24 features loaded
# 25 features loaded
# 16 features loaded
# 30 features loaded
# 26 features loaded
# 17 features loaded
# 31 features loaded
# 27 features loaded
# 18 features loaded
# 28 features loaded
# 32 features loaded
# 19 features loaded
# 33 features loaded
# 35 features loaded
# 5 features loaded
# 34 features loaded
# 36 features loaded
# 40 features loaded
# 6 features loaded
# 37 features loaded
# 41 features loaded
# 7 features loaded
# 42 features loaded
# 43 features loaded
# 38 features loaded
# 44 features loaded
# 8 features loaded
# 12 features loaded
# 29 features loaded
# 9 features loaded
# 13 features loaded
# 50 features loaded
# 55 features loaded
# 14 features loaded
# 51 features loaded
# 39 features loaded
# 45 features loaded
# 56 features loaded
# 60 features loaded
# 46 features loaded
# 65 features loaded
# 57 features loaded
# 61 features loaded
# 66 features loaded
# 62 features loaded
# 58 features loaded
# 52 features loaded
# 67 features loaded
# 63 features loaded
# 59 features loaded
# 53 features loaded
# 68 features loaded
# 47 features loaded
# 70 features loaded
# 54 features loaded
# 48 features loaded
# 69 features loaded
# 75 features loaded
# 71 features loaded
# 80 features loaded
# 49 features loaded
# 76 features loaded
# 72 features loaded
# 64 features loaded
# 81 features loaded
# 85 features loaded
# 77 features loaded
# 73 features loaded
# 82 features loaded
# 86 features loaded
# 78 features loaded
# 74 features loaded
# 83 features loaded
# 87 features loaded
# 79 features loaded
# 95 features loaded
# 90 features loaded
# 88 features loaded
# 96 features loaded
# 89 features loaded
# 91 features loaded
# 97 features loaded
# 84 features loaded
# 92 features loaded
# 98 features loaded
# 93 features loaded
# 94 features loaded
